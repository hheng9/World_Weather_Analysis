# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 612

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description=city_weather["weather"][0]["description"]    
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Description":city_weather_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | upernavik
# Processing Record 2 of Set 1 | esperance
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | nikolskoye
# Processing Record 5 of Set 1 | buala
# Processing Record 6 of Set 1 | vaini
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | puerto ayora
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | georgetown
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | kirkland lake
# Processing Record 15 of Set 1 | rikitea
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | namatanai
# Processing Record 18 of Set 1 | faanui
# Processing Record 19 of Set 1 | saint george
# Processing Record 20 of Set 1 | curup
# Processing Record 21 of Set 1 | jinka
# Processing Record 22 of Set 1 | hilo
# Processing Record 23 of Set 1 | ngukurr
# City not found. Skipping...
# Processing Record 24 of Set 1 | kruisfontein
# Processing Record 25 of Set 1 | saint-joseph
# Processing Record 26 of Set 1 | east london
# Processing Record 27 of Set 1 | el cobre
# Processing Record 28 of Set 1 | superior
# Processing Record 29 of Set 1 | tiksi
# Processing Record 30 of Set 1 | empalme
# Processing Record 31 of Set 1 | vardo
# Processing Record 32 of Set 1 | tierra colorada
# Processing Record 33 of Set 1 | grindavik
# Processing Record 34 of Set 1 | makushino
# Processing Record 35 of Set 1 | kapoeta
# Processing Record 36 of Set 1 | palu
# Processing Record 37 of Set 1 | ancud
# Processing Record 38 of Set 1 | lethem
# Processing Record 39 of Set 1 | lamar
# Processing Record 40 of Set 1 | torbay
# Processing Record 41 of Set 1 | bambous virieux
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | luwingu
# Processing Record 44 of Set 1 | kodiak
# Processing Record 45 of Set 1 | dauphin
# Processing Record 46 of Set 1 | booue
# Processing Record 47 of Set 1 | bluff
# Processing Record 48 of Set 1 | baykit
# Processing Record 49 of Set 1 | abu samrah
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | kalabo
# Processing Record 2 of Set 2 | aklavik
# Processing Record 3 of Set 2 | zaterechnyy
# Processing Record 4 of Set 2 | batemans bay
# Processing Record 5 of Set 2 | mar del plata
# Processing Record 6 of Set 2 | dikson
# Processing Record 7 of Set 2 | aracataca
# Processing Record 8 of Set 2 | hobart
# Processing Record 9 of Set 2 | newport
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | pemangkat
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | ringebu
# Processing Record 14 of Set 2 | albany
# Processing Record 15 of Set 2 | qaanaaq
# Processing Record 16 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 2 | pouebo
# Processing Record 18 of Set 2 | college
# Processing Record 19 of Set 2 | ukiah
# Processing Record 20 of Set 2 | saint pete beach
# Processing Record 21 of Set 2 | paka
# Processing Record 22 of Set 2 | bathsheba
# Processing Record 23 of Set 2 | dianopolis
# City not found. Skipping...
# Processing Record 24 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 2 | laguna
# Processing Record 26 of Set 2 | falealupo
# City not found. Skipping...
# Processing Record 27 of Set 2 | northam
# Processing Record 28 of Set 2 | naze
# Processing Record 29 of Set 2 | sagua de tanamo
# Processing Record 30 of Set 2 | bengkulu
# Processing Record 31 of Set 2 | lebu
# Processing Record 32 of Set 2 | kargasok
# Processing Record 33 of Set 2 | adjuntas
# Processing Record 34 of Set 2 | santa cruz de tenerife
# Processing Record 35 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 2 | severo-kurilsk
# Processing Record 37 of Set 2 | haines junction
# Processing Record 38 of Set 2 | kaspiysk
# Processing Record 39 of Set 2 | natal
# Processing Record 40 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 2 | ialibu
# Processing Record 42 of Set 2 | tanete
# Processing Record 43 of Set 2 | praia da vitoria
# Processing Record 44 of Set 2 | mersing
# Processing Record 45 of Set 2 | coihaique
# Processing Record 46 of Set 2 | kapaa
# Processing Record 47 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 48 of Set 2 | benjamin constant
# Processing Record 49 of Set 2 | hithadhoo
# Processing Record 50 of Set 2 | valparaiso
# Processing Record 1 of Set 3 | berlevag
# Processing Record 2 of Set 3 | lorengau
# Processing Record 3 of Set 3 | butaritari
# Processing Record 4 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | airai
# Processing Record 7 of Set 3 | new norfolk
# Processing Record 8 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 9 of Set 3 | samarai
# Processing Record 10 of Set 3 | carauari
# Processing Record 11 of Set 3 | castro
# Processing Record 12 of Set 3 | san juan
# Processing Record 13 of Set 3 | ouro preto do oeste
# Processing Record 14 of Set 3 | jamestown
# Processing Record 15 of Set 3 | matara
# Processing Record 16 of Set 3 | mount gambier
# Processing Record 17 of Set 3 | khatanga
# Processing Record 18 of Set 3 | colac
# Processing Record 19 of Set 3 | west helena
# Processing Record 20 of Set 3 | fortuna
# Processing Record 21 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 3 | arraial do cabo
# Processing Record 23 of Set 3 | belaya gora
# Processing Record 24 of Set 3 | kez
# Processing Record 25 of Set 3 | kununurra
# Processing Record 26 of Set 3 | policoro
# Processing Record 27 of Set 3 | guntakal
# Processing Record 28 of Set 3 | port elizabeth
# Processing Record 29 of Set 3 | puerto carreno
# Processing Record 30 of Set 3 | sitka
# Processing Record 31 of Set 3 | ankang
# Processing Record 32 of Set 3 | saint-augustin
# Processing Record 33 of Set 3 | balkanabat
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 3 | barrow
# Processing Record 37 of Set 3 | jerantut
# Processing Record 38 of Set 3 | acarau
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | avarua
# Processing Record 41 of Set 3 | kon tum
# Processing Record 42 of Set 3 | los llanos de aridane
# Processing Record 43 of Set 3 | monteagudo
# Processing Record 44 of Set 3 | hvolsvollur
# Processing Record 45 of Set 3 | merke
# Processing Record 46 of Set 3 | kutum
# Processing Record 47 of Set 3 | ribeira grande
# Processing Record 48 of Set 3 | waipawa
# Processing Record 49 of Set 3 | ternate
# Processing Record 50 of Set 3 | urengoy
# Processing Record 1 of Set 4 | lasa
# Processing Record 2 of Set 4 | turayf
# Processing Record 3 of Set 4 | asyut
# Processing Record 4 of Set 4 | provideniya
# Processing Record 5 of Set 4 | anadyr
# Processing Record 6 of Set 4 | atuona
# Processing Record 7 of Set 4 | zabol
# Processing Record 8 of Set 4 | nikel
# Processing Record 9 of Set 4 | bentiu
# Processing Record 10 of Set 4 | gurupa
# Processing Record 11 of Set 4 | uyemskiy
# Processing Record 12 of Set 4 | banff
# Processing Record 13 of Set 4 | aksu
# Processing Record 14 of Set 4 | shelburne
# Processing Record 15 of Set 4 | bredasdorp
# Processing Record 16 of Set 4 | okhotsk
# Processing Record 17 of Set 4 | matay
# Processing Record 18 of Set 4 | nanortalik
# Processing Record 19 of Set 4 | alofi
# Processing Record 20 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 21 of Set 4 | kalemie
# Processing Record 22 of Set 4 | formoso do araguaia
# City not found. Skipping...
# Processing Record 23 of Set 4 | saint-philippe
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | khuzhir
# Processing Record 26 of Set 4 | honningsvag
# Processing Record 27 of Set 4 | nome
# Processing Record 28 of Set 4 | santo antonio do monte
# Processing Record 29 of Set 4 | portland
# Processing Record 30 of Set 4 | salta
# Processing Record 31 of Set 4 | mundo nuevo
# Processing Record 32 of Set 4 | makubetsu
# Processing Record 33 of Set 4 | dumas
# Processing Record 34 of Set 4 | pevek
# Processing Record 35 of Set 4 | kazanlak
# Processing Record 36 of Set 4 | thunder bay
# Processing Record 37 of Set 4 | axim
# Processing Record 38 of Set 4 | vao
# Processing Record 39 of Set 4 | katobu
# Processing Record 40 of Set 4 | tasiilaq
# Processing Record 41 of Set 4 | knysna
# Processing Record 42 of Set 4 | saldanha
# Processing Record 43 of Set 4 | tuatapere
# Processing Record 44 of Set 4 | gotsu
# Processing Record 45 of Set 4 | maniitsoq
# Processing Record 46 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 4 | klyuchi
# Processing Record 48 of Set 4 | usva
# City not found. Skipping...
# Processing Record 49 of Set 4 | chicama
# Processing Record 50 of Set 4 | port blair
# Processing Record 1 of Set 5 | ostrovnoy
# Processing Record 2 of Set 5 | beringovskiy
# Processing Record 3 of Set 5 | yeppoon
# Processing Record 4 of Set 5 | maragogi
# Processing Record 5 of Set 5 | conversion
# Processing Record 6 of Set 5 | cherskiy
# Processing Record 7 of Set 5 | dwarka
# Processing Record 8 of Set 5 | katsuura
# Processing Record 9 of Set 5 | narsaq
# Processing Record 10 of Set 5 | sulam
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | srednekolymsk
# Processing Record 13 of Set 5 | cockburn town
# Processing Record 14 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 15 of Set 5 | marsa matruh
# Processing Record 16 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 17 of Set 5 | brooks
# Processing Record 18 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 19 of Set 5 | flinders
# Processing Record 20 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 21 of Set 5 | mount pleasant
# Processing Record 22 of Set 5 | ilhabela
# Processing Record 23 of Set 5 | ponta do sol
# Processing Record 24 of Set 5 | leningradskiy
# Processing Record 25 of Set 5 | karratha
# Processing Record 26 of Set 5 | roald
# Processing Record 27 of Set 5 | kahului
# Processing Record 28 of Set 5 | sooke
# Processing Record 29 of Set 5 | tall kayf
# Processing Record 30 of Set 5 | cairns
# Processing Record 31 of Set 5 | bismarck
# Processing Record 32 of Set 5 | dicabisagan
# Processing Record 33 of Set 5 | souillac
# Processing Record 34 of Set 5 | benghazi
# Processing Record 35 of Set 5 | manokwari
# Processing Record 36 of Set 5 | timon
# Processing Record 37 of Set 5 | mufumbwe
# Processing Record 38 of Set 5 | repnoye
# Processing Record 39 of Set 5 | longyearbyen
# Processing Record 40 of Set 5 | ulaanbaatar
# Processing Record 41 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 5 | kirkkonummi
# Processing Record 43 of Set 5 | bud
# Processing Record 44 of Set 5 | pisco
# Processing Record 45 of Set 5 | barra patuca
# Processing Record 46 of Set 5 | asau
# Processing Record 47 of Set 5 | saint-leu
# Processing Record 48 of Set 5 | manali
# Processing Record 49 of Set 5 | libertador general san martin
# Processing Record 50 of Set 5 | shihezi
# Processing Record 1 of Set 6 | shahgarh
# Processing Record 2 of Set 6 | codrington
# Processing Record 3 of Set 6 | puerto colombia
# Processing Record 4 of Set 6 | hasaki
# Processing Record 5 of Set 6 | skibbereen
# Processing Record 6 of Set 6 | eureka
# Processing Record 7 of Set 6 | hofn
# Processing Record 8 of Set 6 | nuevo laredo
# Processing Record 9 of Set 6 | byron bay
# Processing Record 10 of Set 6 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 6 | colatina
# Processing Record 12 of Set 6 | san patricio
# Processing Record 13 of Set 6 | constitucion
# Processing Record 14 of Set 6 | sao miguel
# Processing Record 15 of Set 6 | mayskiy
# Processing Record 16 of Set 6 | paita
# Processing Record 17 of Set 6 | afonso claudio
# Processing Record 18 of Set 6 | bodden town
# Processing Record 19 of Set 6 | sur
# Processing Record 20 of Set 6 | minab
# Processing Record 21 of Set 6 | gweru
# Processing Record 22 of Set 6 | goure
# Processing Record 23 of Set 6 | ystad
# Processing Record 24 of Set 6 | snasa
# Processing Record 25 of Set 6 | leshukonskoye
# Processing Record 26 of Set 6 | katherine
# Processing Record 27 of Set 6 | lagoa
# Processing Record 28 of Set 6 | talnakh
# Processing Record 29 of Set 6 | clearwater
# Processing Record 30 of Set 6 | nampa
# Processing Record 31 of Set 6 | kochevo
# Processing Record 32 of Set 6 | lavrentiya
# Processing Record 33 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 34 of Set 6 | ballina
# Processing Record 35 of Set 6 | constantine
# Processing Record 36 of Set 6 | kaitangata
# Processing Record 37 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 6 | grand gaube
# Processing Record 39 of Set 6 | iqaluit
# Processing Record 40 of Set 6 | victor harbor
# Processing Record 41 of Set 6 | cagliliog
# Processing Record 42 of Set 6 | pangody
# Processing Record 43 of Set 6 | tarapur
# Processing Record 44 of Set 6 | zhaotong
# Processing Record 45 of Set 6 | muisne
# Processing Record 46 of Set 6 | litovko
# Processing Record 47 of Set 6 | porto novo
# Processing Record 48 of Set 6 | choszczno
# Processing Record 49 of Set 6 | ndele
# Processing Record 50 of Set 6 | ust-ordynskiy
# Processing Record 1 of Set 7 | ranong
# Processing Record 2 of Set 7 | urupes
# Processing Record 3 of Set 7 | guerrero negro
# Processing Record 4 of Set 7 | vytegra
# Processing Record 5 of Set 7 | namtsy
# Processing Record 6 of Set 7 | along
# Processing Record 7 of Set 7 | burica
# City not found. Skipping...
# Processing Record 8 of Set 7 | ginir
# Processing Record 9 of Set 7 | carutapera
# Processing Record 10 of Set 7 | yarmouth
# Processing Record 11 of Set 7 | chuy
# Processing Record 12 of Set 7 | palmer
# Processing Record 13 of Set 7 | redlands
# Processing Record 14 of Set 7 | lompoc
# Processing Record 15 of Set 7 | englewood
# Processing Record 16 of Set 7 | kuusamo
# Processing Record 17 of Set 7 | darhan
# Processing Record 18 of Set 7 | buzmeyin
# Processing Record 19 of Set 7 | borogontsy
# Processing Record 20 of Set 7 | kavaratti
# Processing Record 21 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 7 | kavieng
# Processing Record 23 of Set 7 | richards bay
# Processing Record 24 of Set 7 | okha
# Processing Record 25 of Set 7 | visby
# Processing Record 26 of Set 7 | zmeinogorsk
# Processing Record 27 of Set 7 | korsakov
# Processing Record 28 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 29 of Set 7 | zhigansk
# Processing Record 30 of Set 7 | ongandjera
# Processing Record 31 of Set 7 | cullera
# Processing Record 32 of Set 7 | bacolod
# Processing Record 33 of Set 7 | nanakuli
# Processing Record 34 of Set 7 | hobyo
# Processing Record 35 of Set 7 | kalaiya
# Processing Record 36 of Set 7 | clyde river
# Processing Record 37 of Set 7 | san cristobal
# Processing Record 38 of Set 7 | ciudad bolivar
# Processing Record 39 of Set 7 | antofagasta
# Processing Record 40 of Set 7 | saint-pierre
# Processing Record 41 of Set 7 | kampene
# Processing Record 42 of Set 7 | menongue
# Processing Record 43 of Set 7 | broome
# Processing Record 44 of Set 7 | cabo san lucas
# Processing Record 45 of Set 7 | lithakia
# Processing Record 46 of Set 7 | si sa ket
# Processing Record 47 of Set 7 | pacific grove
# Processing Record 48 of Set 7 | dingle
# Processing Record 49 of Set 7 | sakakah
# Processing Record 50 of Set 7 | karpogory
# Processing Record 1 of Set 8 | belmonte
# Processing Record 2 of Set 8 | wanning
# Processing Record 3 of Set 8 | ashtabula
# Processing Record 4 of Set 8 | luderitz
# Processing Record 5 of Set 8 | soyo
# Processing Record 6 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 7 of Set 8 | goderich
# Processing Record 8 of Set 8 | geraldton
# Processing Record 9 of Set 8 | polunochnoye
# Processing Record 10 of Set 8 | waddan
# Processing Record 11 of Set 8 | carballo
# Processing Record 12 of Set 8 | marawi
# Processing Record 13 of Set 8 | aasiaat
# Processing Record 14 of Set 8 | yuzhne
# Processing Record 15 of Set 8 | tawau
# Processing Record 16 of Set 8 | alyangula
# Processing Record 17 of Set 8 | lisakovsk
# Processing Record 18 of Set 8 | luis correia
# Processing Record 19 of Set 8 | rio gallegos
# Processing Record 20 of Set 8 | esil
# Processing Record 21 of Set 8 | ahipara
# Processing Record 22 of Set 8 | olafsvik
# Processing Record 23 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 8 | marrakesh
# Processing Record 25 of Set 8 | ha giang
# Processing Record 26 of Set 8 | kaeo
# Processing Record 27 of Set 8 | great falls
# Processing Record 28 of Set 8 | san lawrenz
# Processing Record 29 of Set 8 | baculin
# Processing Record 30 of Set 8 | ponta delgada
# Processing Record 31 of Set 8 | elban
# Processing Record 32 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 33 of Set 8 | haibowan
# City not found. Skipping...
# Processing Record 34 of Set 8 | khanino
# Processing Record 35 of Set 8 | mahebourg
# Processing Record 36 of Set 8 | coulihaut
# City not found. Skipping...
# Processing Record 37 of Set 8 | ozuluama
# Processing Record 38 of Set 8 | sept-iles
# Processing Record 39 of Set 8 | bac lieu
# Processing Record 40 of Set 8 | rio grande
# Processing Record 41 of Set 8 | cayenne
# Processing Record 42 of Set 8 | taunggyi
# Processing Record 43 of Set 8 | xinqing
# Processing Record 44 of Set 8 | tukrah
# Processing Record 45 of Set 8 | ruteng
# Processing Record 46 of Set 8 | krasnoselkup
# Processing Record 47 of Set 8 | lufilufi
# Processing Record 48 of Set 8 | qujing
# Processing Record 49 of Set 8 | bethel
# Processing Record 50 of Set 8 | asayita
# City not found. Skipping...
# Processing Record 1 of Set 9 | puerto ayacucho
# Processing Record 2 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 3 of Set 9 | aswan
# Processing Record 4 of Set 9 | ouadda
# Processing Record 5 of Set 9 | tautira
# Processing Record 6 of Set 9 | vila franca do campo
# Processing Record 7 of Set 9 | gat
# Processing Record 8 of Set 9 | tessalit
# Processing Record 9 of Set 9 | sao felix do xingu
# Processing Record 10 of Set 9 | deputatskiy
# Processing Record 11 of Set 9 | nuuk
# Processing Record 12 of Set 9 | cabedelo
# Processing Record 13 of Set 9 | kholmogory
# Processing Record 14 of Set 9 | cervo
# Processing Record 15 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 16 of Set 9 | amazar
# Processing Record 17 of Set 9 | ust-tsilma
# Processing Record 18 of Set 9 | opuwo
# Processing Record 19 of Set 9 | chifeng
# Processing Record 20 of Set 9 | camacha
# Processing Record 21 of Set 9 | buariki
# City not found. Skipping...
# Processing Record 22 of Set 9 | te anau
# Processing Record 23 of Set 9 | maumere
# Processing Record 24 of Set 9 | san andres
# Processing Record 25 of Set 9 | makung
# City not found. Skipping...
# Processing Record 26 of Set 9 | kresttsy
# Processing Record 27 of Set 9 | sao filipe
# Processing Record 28 of Set 9 | cap malheureux
# Processing Record 29 of Set 9 | port lincoln
# Processing Record 30 of Set 9 | puri
# Processing Record 31 of Set 9 | challapata
# Processing Record 32 of Set 9 | klaksvik
# Processing Record 33 of Set 9 | kloulklubed
# Processing Record 34 of Set 9 | mezen
# Processing Record 35 of Set 9 | huangchuan
# Processing Record 36 of Set 9 | sorland
# Processing Record 37 of Set 9 | avera
# Processing Record 38 of Set 9 | goedereede
# Processing Record 39 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 40 of Set 9 | praia
# Processing Record 41 of Set 9 | pantai remis
# Processing Record 42 of Set 9 | baghdad
# Processing Record 43 of Set 9 | fort dodge
# Processing Record 44 of Set 9 | tilichiki
# Processing Record 45 of Set 9 | sola
# Processing Record 46 of Set 9 | araouane
# Processing Record 47 of Set 9 | moose factory
# Processing Record 48 of Set 9 | mastic beach
# Processing Record 49 of Set 9 | yoichi
# Processing Record 50 of Set 9 | pointe-noire
# Processing Record 1 of Set 10 | mutoko
# Processing Record 2 of Set 10 | buritizeiro
# Processing Record 3 of Set 10 | koplik
# Processing Record 4 of Set 10 | dunmore town
# Processing Record 5 of Set 10 | jonkoping
# Processing Record 6 of Set 10 | santa isabel do rio negro
# Processing Record 7 of Set 10 | hambantota
# Processing Record 8 of Set 10 | fairbanks
# Processing Record 9 of Set 10 | general roca
# Processing Record 10 of Set 10 | fort nelson
# Processing Record 11 of Set 10 | nyurba
# Processing Record 12 of Set 10 | bollnas
# Processing Record 13 of Set 10 | merritt island
# Processing Record 14 of Set 10 | luanda
# Processing Record 15 of Set 10 | aniche
# Processing Record 16 of Set 10 | ogrezeni
# Processing Record 17 of Set 10 | dunedin
# Processing Record 18 of Set 10 | aykhal
# Processing Record 19 of Set 10 | russell
# Processing Record 20 of Set 10 | manta
# Processing Record 21 of Set 10 | snyder
# Processing Record 22 of Set 10 | auki
# Processing Record 23 of Set 10 | darovskoy
# Processing Record 24 of Set 10 | kuloy
# Processing Record 25 of Set 10 | virginia beach
# Processing Record 26 of Set 10 | grand-santi
# Processing Record 27 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 28 of Set 10 | yuanping
# Processing Record 29 of Set 10 | sawakin
# Processing Record 30 of Set 10 | dinajpur
# Processing Record 31 of Set 10 | prainha
# Processing Record 32 of Set 10 | merauke
# Processing Record 33 of Set 10 | henties bay
# Processing Record 34 of Set 10 | westport
# Processing Record 35 of Set 10 | arkhipovka
# Processing Record 36 of Set 10 | paamiut
# Processing Record 37 of Set 10 | beira
# Processing Record 38 of Set 10 | north ogden
# Processing Record 39 of Set 10 | victoria
# Processing Record 40 of Set 10 | qasigiannguit
# Processing Record 41 of Set 10 | bandarbeyla
# Processing Record 42 of Set 10 | bilibino
# Processing Record 43 of Set 10 | vostok
# Processing Record 44 of Set 10 | bonfim
# Processing Record 45 of Set 10 | savinka
# Processing Record 46 of Set 10 | santa fe
# Processing Record 47 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 10 | ipora
# Processing Record 49 of Set 10 | mehamn
# Processing Record 50 of Set 10 | hamilton
# Processing Record 1 of Set 11 | mukhen
# Processing Record 2 of Set 11 | taltal
# Processing Record 3 of Set 11 | faya
# Processing Record 4 of Set 11 | pimentel
# Processing Record 5 of Set 11 | kansk
# Processing Record 6 of Set 11 | isabela
# Processing Record 7 of Set 11 | puerto gaitan
# Processing Record 8 of Set 11 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 11 | kamsack
# Processing Record 10 of Set 11 | marzuq
# Processing Record 11 of Set 11 | vangaindrano
# Processing Record 12 of Set 11 | aksarayskiy
# Processing Record 13 of Set 11 | kirakira
# Processing Record 14 of Set 11 | almora
# Processing Record 15 of Set 11 | liverpool
# Processing Record 16 of Set 11 | the valley
# Processing Record 17 of Set 11 | magnor
# Processing Record 18 of Set 11 | port augusta
# Processing Record 19 of Set 11 | bonavista
# Processing Record 20 of Set 11 | sharon
# Processing Record 21 of Set 11 | tres palos
# Processing Record 22 of Set 11 | djambala
# Processing Record 23 of Set 11 | katubao
# Processing Record 24 of Set 11 | vestmannaeyjar
# Processing Record 25 of Set 11 | mount isa
# Processing Record 26 of Set 11 | vrangel
# Processing Record 27 of Set 11 | sao joao da barra
# Processing Record 28 of Set 11 | indramayu
# Processing Record 29 of Set 11 | sinnamary
# Processing Record 30 of Set 11 | selfoss
# Processing Record 31 of Set 11 | lalomanu
# City not found. Skipping...
# Processing Record 32 of Set 11 | simbahan
# Processing Record 33 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 11 | taoudenni
# Processing Record 35 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 36 of Set 11 | capitao poco
# Processing Record 37 of Set 11 | mayumba
# Processing Record 38 of Set 11 | khandyga
# Processing Record 39 of Set 11 | mugur-aksy
# Processing Record 40 of Set 11 | waingapu
# Processing Record 41 of Set 11 | loandjili
# Processing Record 42 of Set 11 | coro
# Processing Record 43 of Set 11 | verkhnevilyuysk
# Processing Record 44 of Set 11 | tamworth
# Processing Record 45 of Set 11 | half moon bay
# Processing Record 46 of Set 11 | lincoln
# Processing Record 47 of Set 11 | petrozavodsk
# Processing Record 48 of Set 11 | pervomayskoye
# Processing Record 49 of Set 11 | omsukchan
# Processing Record 50 of Set 11 | visnes
# Processing Record 1 of Set 12 | snezhnogorsk
# Processing Record 2 of Set 12 | safford
# Processing Record 3 of Set 12 | cabra
# Processing Record 4 of Set 12 | sumbe
# Processing Record 5 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 6 of Set 12 | san pedro
# Processing Record 7 of Set 12 | touros
# Processing Record 8 of Set 12 | uwayl
# City not found. Skipping...
# Processing Record 9 of Set 12 | cidreira
# Processing Record 10 of Set 12 | lishu
# Processing Record 11 of Set 12 | moscow
# Processing Record 12 of Set 12 | salalah
# Processing Record 13 of Set 12 | fare
# Processing Record 14 of Set 12 | helong
# Processing Record 15 of Set 12 | el dorado
# Processing Record 16 of Set 12 | yulara
# Processing Record 17 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 18 of Set 12 | amasya
# Processing Record 19 of Set 12 | siguiri
# Processing Record 20 of Set 12 | oneonta
# Processing Record 21 of Set 12 | kaka
# Processing Record 22 of Set 12 | candido mendes
# Processing Record 23 of Set 12 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 24 of Set 12 | biak
# Processing Record 25 of Set 12 | sabha
# Processing Record 26 of Set 12 | pringsewu
# Processing Record 27 of Set 12 | creel
# Processing Record 28 of Set 12 | prince george
# Processing Record 29 of Set 12 | port hardy
# Processing Record 30 of Set 12 | shimoda
# Processing Record 31 of Set 12 | braslav
# City not found. Skipping...
# Processing Record 32 of Set 12 | yavaros
# Processing Record 33 of Set 12 | hokitika
# Processing Record 34 of Set 12 | weiswampach
# Processing Record 35 of Set 12 | rock sound
# Processing Record 36 of Set 12 | domoni
# Processing Record 37 of Set 12 | mogadishu
# Processing Record 38 of Set 12 | almeirim
# Processing Record 39 of Set 12 | kaminoyama
# Processing Record 40 of Set 12 | malartic
# Processing Record 41 of Set 12 | kingman
# Processing Record 42 of Set 12 | alugan
# Processing Record 43 of Set 12 | havre-saint-pierre
# Processing Record 44 of Set 12 | zunyi
# Processing Record 45 of Set 12 | lulea
# Processing Record 46 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 12 | morondava
# Processing Record 48 of Set 12 | nizhnevartovsk
# Processing Record 49 of Set 12 | awjilah
# Processing Record 50 of Set 12 | richard toll
# City not found. Skipping...
# Processing Record 1 of Set 13 | mwinilunga
# Processing Record 2 of Set 13 | jumla
# Processing Record 3 of Set 13 | san quintin
# Processing Record 4 of Set 13 | san rafael
# Processing Record 5 of Set 13 | coahuayana
# Processing Record 6 of Set 13 | nouadhibou
# Processing Record 7 of Set 13 | cururupu
# Processing Record 8 of Set 13 | pontianak
# Processing Record 9 of Set 13 | bolshevik
# Processing Record 10 of Set 13 | homer
# Processing Record 11 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 12 of Set 13 | la asuncion
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 560

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Upernavik  72.7868  -56.1549    -12.42        93         100
# 1     Esperance -33.8667  121.9000     66.49        50          53
# 2       Mataura -46.1927  168.8643     72.97        48           3
# 3    Nikolskoye  59.7035   30.7861     33.80        97         100
# 4         Buala  -8.1450  159.5921     80.69        83         100
# 5         Vaini -21.2000 -175.2000     84.36        74          40
# 6   Port Alfred -33.5906   26.8910     81.18        72          86
# 7  Puerto Ayora  -0.7393  -90.3518     74.55        97          48
# 8      Hermanus -34.4187   19.2345     73.80        86          96
# 9       Ushuaia -54.8000  -68.3000     56.86        62           0
#
#    Wind Speed Country Weather Description
# 0        6.53      GL     overcast clouds
# 1       18.86      AU       broken clouds
# 2        4.99      NZ           clear sky
# 3       11.30      RU          light snow
# 4       10.29      SB       moderate rain
# 5        4.61      TO    scattered clouds
# 6       12.73      ZA     overcast clouds
# 7        1.01      EC    scattered clouds
# 8        2.68      ZA     overcast clouds
# 9        3.44      AR           clear sky

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Weather Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Weather Description']

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Upernavik      GL  72.7868  -56.1549    -12.42        93         100
# 1      Esperance      AU -33.8667  121.9000     66.49        50          53
# 2        Mataura      NZ -46.1927  168.8643     72.97        48           3
# 3     Nikolskoye      RU  59.7035   30.7861     33.80        97         100
# 4          Buala      SB  -8.1450  159.5921     80.69        83         100
# ..           ...     ...      ...       ...       ...       ...         ...
# 555     Cururupu      BR  -1.8283  -44.8683     73.00        94          70
# 556    Pontianak      ID  -0.0333  109.3333     89.58        59          75
# 557    Bolshevik      BY  54.0065   27.5692     35.22        99         100
# 558        Homer      US  59.6425 -151.5483     33.76        93         100
# 559  La Asuncion      VE  11.0333  -63.8628     76.73        88          32
#
#      Wind Speed Weather Description
# 0          6.53     overcast clouds
# 1         18.86       broken clouds
# 2          4.99           clear sky
# 3         11.30          light snow
# 4         10.29       moderate rain
# ..          ...                 ...
# 555        2.44       broken clouds
# 556        8.05       broken clouds
# 557        8.77          light snow
# 558        8.01          light snow
# 559        6.91    scattered clouds
#
# [560 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Weather Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
weather_output = "../Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(weather_output, index_label="City_ID")
